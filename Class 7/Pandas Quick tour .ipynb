# %%
import pandas as pd

# %% [markdown]
# #### There are multiple use cases for Pandas, Data analysis being one.

# %%
ser = pd.Series([1,2,3.0,2,4],index=['a','b','c','d','e'])

# %%
print ser['b']
# Out:
# 2.0

# %%
df = pd.DataFrame([{'a':1,'b':2},{'a':3,'b':1}], index=[100,101])

# %%
df.tail(10)
# Out:
#      a  b
# 100  1  2
# 101  3  1

# %%
print df['a'] # Dictionary like querying
print 
print df.a  # Attribute like querying
# Out:
# 100    1
# 101    3
# Name: a, dtype: int64
#
# 100    1
# 101    3
# Name: a, dtype: int64

# %%
df.query('b > 1')
# Out:
#      a  b
# 100  1  2

# %%
# These methods are Deprecated, use iloc instead
print df.irow(1) 
print df.icol(1)
# Out:
# a    3
# b    1
# Name: 101, dtype: int64
# 100    2
# 101    1
# Name: b, dtype: int64
# c:\anaconda2\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: irow(i) is deprecated. Please use .iloc[i]
#   from ipykernel import kernelapp as app
# c:\anaconda2\lib\site-packages\ipykernel\__main__.py:3: FutureWarning: icol(i) is deprecated. Please use .iloc[:,i]
#   app.launch_new_instance()

# %%
print df.iloc[1]  # prints the second row
print df.iloc[:,1] # prints the second column all rows
print df.iloc[1,1] # prints second row , second column
# Out:
# a    3
# b    1
# Name: 101, dtype: int64
# 100    2
# 101    1
# Name: b, dtype: int64
# 1

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
df.plot.scatter(x='a',y='b')

# %%
df.fillna(0)
# Out:
#      a  b  z
# 100  1  2  0
# 101  3  1  0

# %%
import urllib2, json

# %%
data = urllib2.urlopen("https://opentdb.com/api.php?amount=10&category=18&difficulty=easy&type=multiple").read()
data = json.loads(data)
print data
quiz = pd.DataFrame(data['results'])
quiz.head(10)
# Out:
# {u'response_code': 0, u'results': [{u'category': u'Science: Computers', u'type': u'multiple', u'question': u'In any programming language, what is the most common way to iterate through an array?', u'difficulty': u'easy', u'correct_answer': u'&#039;For&#039; loops', u'incorrect_answers': [u'&#039;If&#039; Statements', u'&#039;Do-while&#039; loops', u'&#039;While&#039; loops']}, {u'category': u'Science: Computers', u'type': u'multiple', u'question': u'How many bytes are in a kilobyte of RAM?', u'difficulty': u'easy', u'correct_answer': u'1024', u'incorrect_answers': [u'512', u'1000', u'500']}, {u'category': u'Science: Computers', u'type': u'multiple', u'question': u'When Gmail first launched, how much storage did it provide for your email?', u'difficulty': u'easy', u'correct_answer': u'1GB', u'incorrect_answers': [u'512MB', u'5GB', u'Unlimited']}, {u'category': u'Science: Computers', u'type': u'multiple', u'question': u'The programming language &#039;Swift&#039; was created to replace 
# ...

# %%
quiz
# Out:
# array([u'Science: Computers'], dtype=object)

# %%
hr_data = pd.read_csv('HR_EMP_ATTRITION.csv')
print len(hr_data)
print hr_data.columns
print hr_data.shape
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-29-4bdac5fa4b64> in <module>()
# ----> 1 hr_data = pd.read_csv('HR_EMP_ATTRITION.csv')
#       2 print len(hr_data)
#       3 print hr_data.columns
#       4 print hr_data.shape
#
# ...

# %%
hr_data.corr()
# Out:
#                               ﻿Age  DailyRate  DistanceFromHome  Education  \
# ﻿Age                      1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %%
df = pd.DataFrame([{'a':1,'b':2},{'a':3,'b':1},{'a':10,'b':9}], index=[100,101,102])
ff = pd.DataFrame([{'z':89,'b':2},{'z':87,'b':1}], index=[100,101])

# %%
import numpy as np

# %%
data = np.arange(20)

# %%
plt.subplot(222)
plt.scatter(data, data**2, color='R', marker='o')
plt.scatter(data, data**3, color='B', marker='*')
plt.subplot(223)

# %%
plt.subplot?
